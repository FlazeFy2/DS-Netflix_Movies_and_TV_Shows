# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("netflix_titles.csv")

# Data Understanding - Variable & Data Type
print(df.dtypes)
print("\n")
print(f"{len(df.columns)} Column")
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object
#
#
# 12 Column

# %%
# Data Preparation - Handle Missing Value
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
plt.boxplot(df['release_year'])
plt.title(f'Boxplot of Release Year')
plt.show()

# %%
# Data Preparation - Invalid Value
ratio_column = ['release_year']
for dt in ratio_column:
    invalid_prices = df[df[dt] < 0]
    print(invalid_prices.index)
# Out:
# Index([], dtype='int64')
